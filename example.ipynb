# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from playground_scm.doscm import get_batch

# %%
hyperparameters = {
    'num_unobserved': 2,
    'seed' : 42,
    'noise_std': 0.01,
    'exo_std': 0.1,
    'noise_dist': 'gaussian',
    'exo_dist': 'gaussian',
    'nonlins': 'mixed',
    'max_hidden_layers': 0,
    'zero_one_treatment': True,
    'nonlin_type': 'pre',
    'binary_strategy': 'extreme',
    # to speficy a specific graph
    'graph': None,
    't_idx': None,
    'y_idx': None,
    'x_idcs': None
}

x_obs, y_obs, y_int, x_int, do_scm = get_batch(
    batch_size = 4,
    seq_len = 1000, 
    num_features = 5,
    hyperparameters = hyperparameters,
    device = 'cpu',
    num_outputs = 1,
    num_treatments = 1,    
    return_SCM = True,
)
